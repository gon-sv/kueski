# %% [markdown]
# # MLE challenge - Features engineering

# %% [markdown]
# ### Notebook 1

# %% [markdown]
# In this notebook we compute five features for the **credit risk** dataset.
# Each row in the dataset consists of the credit that a user took on a given date.
#
# These features are roughly defined as follows:
#
# **nb_previous_loans:** number of loans granted to a given user, before the current loan.
#
# **avg_amount_loans_previous:** average amount of loans granted to a user, before the current rating.
#
# **age:** user age in years.
#
# **years_on_the_job:** years the user has been in employment.
#
# **flag_own_car:** flag that indicates if the user has his own car.

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_credit_risk.csv')

# %%
df
# Out:
#         loan_id       id code_gender flag_own_car flag_own_realty  \
# 0        208089  5044500           F            N               Y
# 1        112797  5026631           F            N               Y
# 2        162434  5036645           M            Y               N
# 3        144343  5033584           F            N               Y
# 4        409695  5085755           F            Y               Y
# ...         ...      ...         ...          ...             ...
# 777710    46869  5021552           F            N               Y
# 777711   520468  5117453           F            N               N
# 777712   375790  5067951           F            N               Y
# 777713     2763  5008914           F            N               Y
# 777714    24163  5010182           M            N               N
#
#         cnt_children  amt_income_total      name_income_type  \
# 0                  0           45000.0             Pensioner
# 1                  0           99000.0               Working
# 2                  0          202500.0               Working
# 3                  0          292500.0               Working
# 4                  1          112500.0  Commercial associate
# ...              ...               ...                   ...
# 777710             0          202500.0  Commercial associate
# 777711             2           90000.0               Working
# 777712             0          157500.0  Commercial associate
# 777713             0          297000.0  Commercial associate
# 777714             1          247500.0               Working
#
#                   name_education_type    name_family_status  ...  \
# 0       Secondary / secondary special                 Widow  ...
# 1       Secondary / secondary special             Separated  ...
# 2                   Incomplete higher               Married  ...
# 3                    Higher education               Married  ...
# 4       Secondary / secondary special        Civil marriage  ...
# ...                               ...                   ...  ...
# 777710  Secondary / secondary special               Married  ...
# 777711  Secondary / secondary special               Married  ...
# 777712  Secondary / secondary special  Single / not married  ...
# 777713  Secondary / secondary special  Single / not married  ...
# 777714  Secondary / secondary special  Single / not married  ...
#
#        flag_work_phone  flag_phone  flag_email  occupation_type  \
# 0                    0           0           0              NaN
# 1                    0           0           0   Medicine staff
# 2                    0           0           0          Drivers
# 3                    0           0           0              NaN
# 4                    0           0           0       Core staff
# ...                ...         ...         ...              ...
# 777710               0           0           0   Medicine staff
# 777711               1           0           0              NaN
# 777712               0           1           1              NaN
# 777713               0           0           0         Laborers
# 777714               0           1           0         Laborers
#
#         cnt_fam_members  status    birthday job_start_date   loan_date  \
# 0                   1.0       0  1955-08-04     3021-09-18  2019-01-01
# 1                   1.0       0  1972-03-30     1997-06-05  2019-01-01
# 2                   2.0       0  1987-03-24     2015-02-22  2019-01-01
# 3                   2.0       0  1973-03-15     2009-06-29  2019-01-01
# 4                   3.0       0  1989-10-15     2019-07-03  2019-01-01
# ...                 ...     ...         ...            ...         ...
# 777710              2.0       0  1964-07-28     2017-05-18  2020-12-30
# 777711              4.0       0  1989-03-26     2021-06-13  2020-12-30
# 777712              1.0       0  1972-01-25     2011-11-18  2020-12-30
# 777713              1.0       0  1979-03-23     2012-11-09  2020-12-30
# 777714              2.0       0  1975-09-22     2003-09-09  2020-12-30
#
#         loan_amount
# 0        133.714974
# 1        158.800558
# 2        203.608487
# 3        113.204964
# 4        109.376260
# ...             ...
# 777710   156.011689
# 777711   181.019600
# 777712   128.972541
# 777713   132.357583
# 777714   102.045595
#
# [777715 rows x 24 columns]

# %%
df.shape
# Out:
# (777715, 24)

# %%
df = df.sort_values(by=["id", "loan_date"])
df = df.reset_index(drop=True)
df["loan_date"] = pd.to_datetime(df.loan_date)
df.head(2)
# Out:
#    loan_id       id code_gender flag_own_car flag_own_realty  cnt_children  \
# 0     1008  5008804           M            Y               Y             0
# 1     1000  5008804           M            Y               Y             0
#
#    amt_income_total name_income_type name_education_type name_family_status  \
# 0          427500.0          Working    Higher education     Civil marriage
# 1          427500.0          Working    Higher education     Civil marriage
#
#    ... flag_work_phone  flag_phone  flag_email  occupation_type  \
# 0  ...               1           0           0              NaN
# 1  ...               1           0           0              NaN
#
#    cnt_fam_members  status    birthday job_start_date  loan_date  loan_amount
# 0              2.0       0  1988-11-04     2009-04-11 2019-02-01   102.283361
# 1              2.0       0  1988-11-04     2009-04-11 2019-02-15   136.602049
#
# [2 rows x 24 columns]

# %% [markdown]
# #### Feature nb_previous_loans

# %%
df_grouped = df.groupby("id")
df["nb_previous_loans"] = df_grouped["loan_date"].rank(method="first") - 1

# %% [markdown]
# #### Feature avg_amount_loans_previous

# %%
df['avg_amount_loans_previous'] = (
    df.groupby('id')['loan_amount'].apply(lambda x: x.shift().expanding().mean())
)

# %% [markdown]
# #### Feature age

# %%
from datetime import datetime, date

# %%
df['birthday'] = pd.to_datetime(df['birthday'], errors='coerce')

# %%
df['age'] = (pd.to_datetime('today').normalize() - df['birthday']).dt.days // 365

# %% [markdown]
# #### Feature years_on_the_job

# %%
df['job_start_date'] = pd.to_datetime(df['job_start_date'], errors='coerce')

# %%
df['years_on_the_job'] = (pd.to_datetime('today').normalize() - df['job_start_date']).dt.days // 365

# %% [markdown]
# #### Feature flag_own_car

# %%
df['flag_own_car'] = df.flag_own_car.apply(lambda x : 0 if x == 'N' else 1)

# %% [markdown]
# ## Save dataset for model training

# %%
df = df[['id', 'age', 'years_on_the_job', 'nb_previous_loans', 'avg_amount_loans_previous', 'flag_own_car', 'status']]
df
# Out:
#              id  age  years_on_the_job  nb_previous_loans  \
# 0       5008804   33              13.0                0.0
# 1       5008804   33              13.0                1.0
# 2       5008804   33              13.0                2.0
# 3       5008804   33              13.0                3.0
# 4       5008804   33              13.0                4.0
# ...         ...  ...               ...                ...
# 777710  5150487   53               6.0               25.0
# 777711  5150487   53               6.0               26.0
# 777712  5150487   53               6.0               27.0
# 777713  5150487   53               6.0               28.0
# 777714  5150487   53               6.0               29.0
#
#         avg_amount_loans_previous  flag_own_car  status
# 0                             NaN             1       0
# 1                      102.283361             1       0
# 2                      119.442705             1       0
# 3                      117.873035             1       0
# 4                      114.289538             1       0
# ...                           ...           ...     ...
# 777710                 132.585287             1       0
# 777711                 132.016323             1       0
# 777712                 131.044545             1       0
# 777713                 130.375785             1       0
# 777714                 129.798262             1       0
#
# [777715 rows x 7 columns]

# %%
df.to_csv('train_model.csv', index=False)
